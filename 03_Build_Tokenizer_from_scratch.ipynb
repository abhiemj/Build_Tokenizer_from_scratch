# %% [markdown]
# ## Prepared by : Abhishek Choraria
#   **Linkedin** : https://www.linkedin.com/in/abhishek-choraria-b0966a67/
#
#   **Github** : https://github.com/abhiemj

# %%
import torch
import re

# %%
## read the text file and append all lines to a list

list_of_unique_words = []
with open('/content/unique_words.txt','r',encoding='utf-8') as f:
  ## read all line
  list_of_unique_words = f.readlines()

list_of_unique_words[:5]
# Out:
# ['a\n', 'aa\n', 'aaa\n', 'aaaa\n', 'aabattery\n']

# %%
#3 remove the newline character from each lines
unique_words = []
for word in list_of_unique_words:
  unique_words.append(word.strip())

# %%
unique_words[:10]
# Out:
# ['a',
#  'aa',
#  'aaa',
#  'aaaa',
#  'aabattery',
#  'aaczel',
#  'aak',
#  'aan',
#  'aand',
#  'aandb']

# %%
## join all words

unique_words = ' '.join(unique_words)
unique_words
# Out:
# 'a aa aaa aaaa aabattery aaczel aak aan aand aandb aandbare aandbas aandbis aar ab abacuses abar abasic abbabaa abbey abbreviated abc abcd abcde abcdef abcells abcn abetter abf abfigure abilistic abilities ability able ables ablock ably abn abnormal abolition abook abort aborted about abouta aboutantitrust aboutexperimental aboutpopulation aboutpro aboutprobability aboutregression aboutthe abouttrimming above aboveor abox abraham abroad abrupt absence absent absolute absoluteerrors absolutely absolutelyuseless absolutevalue abstracts abuse abusiness ac academic academicpress academy acc accept acceptability acceptable acceptance acceptancenumber accepted accepting acceptit accepts access accessible accessibleviastat accident accidental accidentally accidents acclaimed accom accommodate accommodatesdata accommodations accompanies accompany accompanying accomplishment accordance according accordingly accordingto account accountant accountants accounted accounting accounts accruals accu accuracy accurate accurately accused ace aceof aceramics aces acetylene achance achemical achievable achieve achieved achievement aclaim acoin acolumn acombination acompany acomplete acompletely acon aconstant acontinuity acontinuous acontrol acorn acorrelation acousin acquainted acquire acquired acquisi acquisition acquisitions acronym across acrossthe act acter acteristics acti acting action actionbranch actionis actions actionsst actionto activates activation active activist activities activity actor actress actresses actressesequally actressesthe acts actu actual actualestimates actually actuallyequal actuallytrue actualp actualproportion actualthe actualvalue acura acurve acustomer aczel ad adaptation adapted adaptive adata add added addedin addedtogether addi addict adding addison addition additional additionalcash additionally additionto additive address addressed adds addup ade adecision adecrease adeep adefect adelman adependence adequate adequately adescription adesign adeveloping adheres adidas adiscrete adiscriminant adivision adj adjacent adjoining adjust adjusted adjustedcoefficient adjustedr adjusting adjustingthe adjustment adjustments adjusts adjustthe admin administered administra administration administrative administrator administrators admired admissionfee admit admits admitted adopt adopted adopting ads adult adults advan advance advanced advancedaspects advancedmathematical advancedmethods advances advantage advantageous advantages advent adventure adventuress adver adversarial adverse adversely advert adverti advertis advertise advertised advertisement advertisements advertiser advertisers advertises advertising advertisingand advertisingexpenditure advi advice advisable advise advisethe advocate advocated advsqr advt adweek adwill ae aenter aerobics aerospace aetna af afactor afew affairs affect affected affecting affective affects affectsthe affectthe affiliates affine affluent afford affordable affords afigure aforementioned aframe afrequency africa african after afterall afterde afterentering afternoon afterward afterway afterwhich ag again against againstit againstthese age aged agegroups ageis agement agemoves agen agencies agency agencydecides agent agents ager agers ages aggregate aggregated aggregatedresponse aggregatethe aggregating aggressive agilent aging agiven agives ago agood agoodness agrarian agree agreed agreeing agreement agreements agreen agrees agri agricultural agroup aguess ah ahas ahead aheart ahigher ahistogram ahoo ai aiare aid aids aif aijare aim aimed aiming aims ain air airbag airbags airbus aircraft aired aires airing airings airl airline airlineincrease airlines airlineservice airplane airplanes airport airports airw airways ais aisles aiting aizenman ajoint ak akare akbe ake aknown akxk akxkwill al alan alarge alarm alarmed alas alaska alathe albuquerque alcan alcohol alcoholic alcoholicbeverages alert alerted alevels alex alexander alexandria alexei alfa alfasud alfred algebra algebraic alge ...

# %% [markdown]
# ## Deine special tokens

# %%
initial_token = '[initial]'
final_token = '[final]'
mysterious_token = '[mysterious]'
padded_token = '[PAD]' # add pad in extra space

# %%
## deine a function to tokenize the words,

def create_tokens(text):
  return re.findall(r"[\w']+|[.,!?]",text.lower())

# %%
text = "I am builduing a tokenizer"

tokens = create_tokens(text)

print(tokens)
# Out:
# ['i', 'am', 'builduing', 'a', 'tokenizer']

# %%
## convert our unique words into tokens

tokens = create_tokens(unique_words)

## convert the tokens into unique tokens
unique_tokens = list(set(tokens))

## sort them

unique_tokens.sort()

print(unique_tokens)
# Out:
# ['a', 'aa', 'aaa', 'aaaa', 'aabattery', 'aaczel', 'aak', 'aan', 'aand', 'aandb', 'aandbare', 'aandbas', 'aandbis', 'aar', 'ab', 'abacuses', 'abar', 'abasic', 'abbabaa', 'abbey', 'abbreviated', 'abc', 'abcd', 'abcde', 'abcdef', 'abcells', 'abcn', 'abetter', 'abf', 'abfigure', 'abilistic', 'abilities', 'ability', 'able', 'ables', 'ablock', 'ably', 'abn', 'abnormal', 'abolition', 'abook', 'abort', 'aborted', 'about', 'abouta', 'aboutantitrust', 'aboutexperimental', 'aboutpopulation', 'aboutpro', 'aboutprobability', 'aboutregression', 'aboutthe', 'abouttrimming', 'above', 'aboveor', 'abox', 'abraham', 'abroad', 'abrupt', 'absence', 'absent', 'absolute', 'absoluteerrors', 'absolutely', 'absolutelyuseless', 'absolutevalue', 'abstracts', 'abuse', 'abusiness', 'ac', 'academic', 'academicpress', 'academy', 'acc', 'accept', 'acceptability', 'acceptable', 'acceptance', 'acceptancenumber', 'accepted', 'accepting', 'acceptit', 'accepts', 'access', 'accessible', 'accessibleviastat', 'accident', 'accidental', 'accidentally', 'accidents', 'acclaimed', 'accom', 'accommodate', 'accommodatesdata', 'accommodations', 'accompanies', 'accompany', 'accompanying', 'accomplishment', 'accordance', 'according', 'accordingly', 'accordingto', 'account', 'accountant', 'accountants', 'accounted', 'accounting', 'accounts', 'accruals', 'accu', 'accuracy', 'accurate', 'accurately', 'accused', 'ace', 'aceof', 'aceramics', 'aces', 'acetylene', 'achance', 'achemical', 'achievable', 'achieve', 'achieved', 'achievement', 'aclaim', 'acoin', 'acolumn', 'acombination', 'acompany', 'acomplete', 'acompletely', 'acon', 'aconstant', 'acontinuity', 'acontinuous', 'acontrol', 'acorn', 'acorrelation', 'acousin', 'acquainted', 'acquire', 'acquired', 'acquisi', 'acquisition', 'acquisitions', 'acronym', 'across', 'acrossthe', 'act', 'acter', 'acteristics', 'acti', 'acting', 'action', 'actionbranch', 'actionis', 'actions', 'actionsst', 'actionto', 'activates', 'activation', 'active', 'activist', 'activities', 'activity', 'actor', 'actress', 'actresses', 'actressesequally', 'actressesthe', 'acts', 'actu', 'actual', 'actualestimates', 'actually', 'actuallyequal', 'actuallytrue', 'actualp', 'actualproportion', 'actualthe', 'actualvalue', 'acura', 'acurve', 'acustomer', 'aczel', 'ad', 'adaptation', 'adapted', 'adaptive', 'adata', 'add', 'added', 'addedin', 'addedtogether', 'addi', 'addict', 'adding', 'addison', 'addition', 'additional', 'additionalcash', 'additionally', 'additionto', 'additive', 'address', 'addressed', 'adds', 'addup', 'ade', 'adecision', 'adecrease', 'adeep', 'adefect', 'adelman', 'adependence', 'adequate', 'adequately', 'adescription', 'adesign', 'adeveloping', 'adheres', 'adidas', 'adiscrete', 'adiscriminant', 'adivision', 'adj', 'adjacent', 'adjoining', 'adjust', 'adjusted', 'adjustedcoefficient', 'adjustedr', 'adjusting', 'adjustingthe', 'adjustment', 'adjustments', 'adjusts', 'adjustthe', 'admin', 'administered', 'administra', 'administration', 'administrative', 'administrator', 'administrators', 'admired', 'admissionfee', 'admit', 'admits', 'admitted', 'adopt', 'adopted', 'adopting', 'ads', 'adult', 'adults', 'advan', 'advance', 'advanced', 'advancedaspects', 'advancedmathematical', 'advancedmethods', 'advances', 'advantage', 'advantageous', 'advantages', 'advent', 'adventure', 'adventuress', 'adver', 'adversarial', 'adverse', 'adversely', 'advert', 'adverti', 'advertis', 'advertise', 'advertised', 'advertisement', 'advertisements', 'advertiser', 'advertisers', 'advertises', 'advertising', 'advertisingand', 'advertisingexpenditure', 'advi', 'advice', 'advisable', 'advise', 'advisethe', 'advocate', 'advocated', 'advsqr', 'advt', 'adweek', 'adwill', 'ae', 'aenter', 'aerobics', 'aerospace', 'aetna', 'af', 'afactor', 'afew', 'affairs', 'affect', 'affected', 'affecting', 'affective', 'affects', 'affectsthe', 'affectthe', 'affiliates', 'affine', 'affluent', 'afford', 'affordable', 'affords', 'afigure', 'aforementioned', 'aframe', 'afrequency', 'africa', 'african', ' ...

# %%
reordered_tokens = []

for token in unique_tokens:
  if token not in (initial_token,final_token,mysterious_token,padded_token):
      reordered_tokens.append(token)

## Append special tokens at end
reordered_tokens.append(initial_token)
reordered_tokens.append(final_token)
reordered_tokens.append(mysterious_token)
reordered_tokens.append(padded_token)

# %%
print("first 10 tokens:", reordered_tokens[:10])
print("Last 10 tokens:", reordered_tokens[-10:])
# Out:
# first 10 tokens: ['a', 'aa', 'aaa', 'aaaa', 'aabattery', 'aaczel', 'aak', 'aan', 'aand', 'aandb']
# Last 10 tokens: ['zwill', 'zwith', 'zx', 'zz', 'zzz', 'zzzz', '[initial]', '[final]', '[mysterious]', '[PAD]']

# %%
## Assign index to each token

# Assign index to each token
word_to_id = {}
for id, token in enumerate(reordered_tokens):
    word_to_id[token] = id

# %%
## print id of word
word_to_id['above']
# Out:
# 53

# %%
## id to word
id_to_word = {}
for token,id in word_to_id.items():
  id_to_word[id] = token

# %%
## get the word from id
id_to_word[53]
# Out:
# 'above'

# %%
## define token ids for special tokens
Initial_token_id = word_to_id[initial_token]
final_token_id = word_to_id[final_token]
Mysterious_token_id = word_to_id[mysterious_token]
pad_token_id = word_to_id[padded_token]

# %%
print(f"start token : { initial_token} - ID {Initial_token_id}")
print(f"End token : {final_token} - ID {final_token_id}")
print(f"Mysterious token : {mysterious_token} - ID {Mysterious_token_id}")
print(f"start token : {padded_token} - ID {pad_token_id}")
# Out:
# start token : [initial] - ID 17091
# End token : [final] - ID 17092
# Mysterious token : [mysterious] - ID 17093
# start token : [PAD] - ID 17094

# %% [markdown]
# ## Encoded Function

# %%
import torch

"""
    Encode the text into a sequence of token IDs, with optional truncation.

    Parameters:
    - text: The text to encode.
    - max_length: The maximum length of the token sequence after encoding.
    - truncation: Whether to truncate the sequence to max_length.

    Returns:
    - A list of token IDs representing the encoded text.
    """

def encoder(text, max_length=None, truncate=False, return_tensors=False):

    # create tokens of input text
    tokens = create_tokens(text)

    # Encoding tokens using a for loop
    encoded_tokens = []
    for token in tokens:
        token_id = word_to_id.get(token, word_to_id[mysterious_token])
        encoded_tokens.append(token_id)

    ## add the start and end tokens
    encoded_tokens = [word_to_id[initial_token]] + encoded_tokens + [word_to_id[final_token]]

    # Handling truncation
    if truncate and max_length is not None:
      encoded_tokens = encoded_tokens[:max_length - 1] + [word_to_id[final_token]]


    # Convert to tensor if return_tensors is True
    if return_tensors:
        encoded_tokens = torch.tensor([encoded_tokens])

    return encoded_tokens

# %%
text = "Distinguish between qualitative and quantitative data"
encoded_tokens = encoder(text)
encoded_tokens
# Out:
# [17091, 4227, 1894, 11613, 657, 11626, 3646, 17092]

# %% [markdown]
# ## Decode Function

# %%
## Decode Function

# %%
def decoder(index,skip_special_tokens=False):
  if isinstance(index,torch.Tensor):
    index = index.tolist()

  special_token_ids = set()
  if skip_special_tokens:
    special_token_ids.update([
        Initial_token_id,
        final_token_id,
        Mysterious_token_id,
        pad_token_id,
    ])

  words = []
  for id in index:
    if id not in special_token_ids:
      word = id_to_word[id]

      words.append(word)
  return ' '.join(words)

# %%
decode_text = decoder(encoded_tokens)
decode_text
# Out:
# '[initial] distinguish between qualitative and quantitative data [final]'

# %% [markdown]
# ## Add up everything and define a class

# %%
class myTokenizer:
  def __init__(self,text):
    ## define special tokens
    self.initial_token = '[initial]'
    self.final_token = '[final]'
    self.mysterious_token = '[mysterious]'
    self.padded_token = '[PAD]'

    ## Tokenize the input text
    tokens = self.create_tokens(text)
    ## get the unique tokens
    unique_tokens = list(set(tokens))

    ## sort the tokens to ensure considtent indexing
    unique_tokens.sort()


    ## Add special tokens
    reordered_tokens = []
    for token in unique_tokens:
      if token not in (self.initial_token,self.final_token,self.mysterious_token,self.padded_token):
          reordered_tokens.append(token)

    ## Append special tokens at end
    reordered_tokens.append(self.initial_token)
    reordered_tokens.append(self.final_token)
    reordered_tokens.append(self.mysterious_token)
    reordered_tokens.append(self.padded_token)

    # Assign index to each token
    self.word_to_id = {}
    for id, token in enumerate(reordered_tokens):
        self.word_to_id[token] = id

    # Assign token to each index
    self.id_to_word = {}
    for token,id in word_to_id.items():
      self.id_to_word[id] = token

    ## define token ids for special tokens
    self.Initial_token_id = word_to_id[initial_token]
    self.final_token_id = word_to_id[final_token]
    self.Mysterious_token_id = word_to_id[mysterious_token]
    self.pad_token_id = word_to_id[padded_token]


  ## deine a function to tokenize the words
  def create_tokens(self,text):
    return re.findall(r"[\w']+|[.,!?]",text.lower())

  ## define encoder
  """
    Encode the text into a sequence of token IDs, with optional truncation.

    Parameters:
    - text: The text to encode.
    - max_length: The maximum length of the token sequence after encoding.
    - truncation: Whether to truncate the sequence to max_length.

    Returns:
    - A list of token IDs representing the encoded text.
    """

  def encoder(self,text, max_length=None, truncate=False, return_tensors=False):

      # create tokens of input text
      tokens = self.create_tokens(text)

      # Encoding tokens using a for loop
      encoded_tokens = []
      for token in tokens:
          token_id = self.word_to_id.get(token, self.word_to_id[self.mysterious_token])
          encoded_tokens.append(token_id)

      ## add the start and end tokens
      encoded_tokens = [self.word_to_id[self.initial_token]] + encoded_tokens + [self.word_to_id[self.final_token]]

      # Handling truncation
      if truncate and max_length is not None:
        encoded_tokens = encoded_tokens[:max_length - 1] + [self.word_to_id[self.final_token]]


      # Convert to tensor if return_tensors is True
      if return_tensors:
          encoded_tokens = torch.tensor([encoded_tokens])

      return encoded_tokens

  ## define decoder
  def decoder(self,index,skip_special_tokens=False):
    if isinstance(index,torch.Tensor):
      index = index.tolist()

    special_token_ids = set()
    if skip_special_tokens:
      special_token_ids.update([
          self.Initial_token_id,
          self.final_token_id,
          self.Mysterious_token_id,
          self.pad_token_id,
      ])

    words = []
    for id in index:
      if id not in special_token_ids:
        word = self.id_to_word[id]

        words.append(word)
    return ' '.join(words)

# %%
tokenizer = myTokenizer(unique_words)
encoded_text = tokenizer.encoder("Distinguish between qualitative and quantitative data")
decoded_text = tokenizer.decoder(encoded_text)

print(f"Encoded : {encoded_text}")
print(f"Decoded : {decoded_text}")
# Out:
# Encoded : [17091, 4227, 1894, 11613, 657, 11626, 3646, 17092]
# Decoded : [initial] distinguish between qualitative and quantitative data [final]
